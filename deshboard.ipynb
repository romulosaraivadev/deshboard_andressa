# %%
# Importar base de dados
# importar pasta da planilha DRE
    # grafico de coluna mostrando os custos de o lucro por mes
# Importar pasta da planilha Custos
    # comparar as categorias com o total do custo
# Visualizar base de dados
# Corrigir base de dados

# passo 1: importar base de dados
import pandas as pd
# tabela_dre = pd.read_excel('Mapa_Financeiro_LPM_2023.xlsx', sheet_name='DRE')
tabela = pd.read_excel("Mapa_Financeiro_LPM_2023.xlsx", sheet_name=1)

# passo 2: vizualizar as tabelas
# display(tabela_dre)
display(tabela)
# Out:
#            Tipo       Data     Entidade  Categoria            Descrição  \
# 0      Despesas 2023-07-16  Restaurante  Alimentos               Carnes
# 1      Despesas 2023-07-16  Restaurante  Alimentos               Carnes
# 2      Despesas 2023-07-17  Restaurante  Alimentos               Carnes
# 3      Despesas 2023-07-17  Restaurante  Alimentos  Alimentos e Limpeza
# 4      Despesas 2023-07-17  Restaurante  Alimentos  Alimentos e Limpeza
# ...         ...        ...          ...        ...                  ...
# 20215       NaN        NaT          NaN        NaN                  NaN
# 20216       NaN        NaT          NaN        NaN                  NaN
# 20217       NaN        NaT          NaN        NaN                  NaN
# 20218       NaN        NaT          NaN        NaN                  NaN
# 20219       NaN        NaT          NaN        NaN                  NaN
#
#                 Nome  Forma de Pagamento Nota Fiscal  Indicador  Entrada  \
# 0      Pão de Açúcar             pag pix         NaN        0.0      NaN
# 1      Pão de Açúcar             pag pix         NaN        0.0      NaN
# 2      Pão de Açúcar         cnl pix pag         NaN        0.0      NaN
# 3         Mãe Rainha  Compra com Cartão          NaN        0.0      NaN
# 4                J&L  Compra com Cartão          NaN        0.0      NaN
# ...              ...                 ...         ...        ...      ...
# 20215            NaN                 NaN         NaN        0.0      NaN
# 20216            NaN                 NaN         NaN        0.0      NaN
# 20217            NaN                 NaN         NaN        0.0      NaN
# 20218            NaN                 NaN         NaN        0.0      NaN
# 20219            NaN                 NaN         NaN        0.0      NaN
#
#          Saída  Modo de ajuste    Saldo  Mês  Unnamed: 14 Unnamed: 15  \
# 0      1225.55             NaN -1225.55  7.0          NaN         NaN
# 1      1203.64             NaN -2429.19  7.0          NaN         NaN
# 2       908.16             NaN -3337.35  7.0          NaN         NaN
# 3       615.89             NaN -3953.24  7.0          NaN         NaN
# 4        59.02             NaN -4012.26  7.0          NaN         NaN
# ...        ...             ...      ...  ...          ...         ...
# 20215      NaN             NaN      NaN  NaN          NaN         NaN
# 20216      NaN             NaN      NaN  NaN          NaN         NaN
# 20217      NaN             NaN      NaN  NaN          NaN         NaN
# 20218      NaN             NaN      NaN  NaN          NaN         NaN
# 20219      NaN             NaN      NaN  NaN          NaN         NaN
#
#        Unnamed: 16  Unnamed: 17 Unnamed: 18
# 0              NaN          NaN       Total
# 1              NaN          NaN         NaN
# 2              NaN          NaN         NaN
# 3              NaN          NaN         NaN
# 4              NaN          NaN         NaN
# ...            ...          ...         ...
# 20215          NaN          NaN         NaN
# 20216          NaN          NaN         NaN
# 20217          NaN          NaN         NaN
# 20218          NaN          NaN         NaN
# 20219          NaN          NaN         NaN
#
# [20220 rows x 19 columns]

# %%
# display(tabela_dre.info())
display(tabela['Tipo', 'Despesas'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\romel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Tipo', 'Despesas')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 # display(tabela_dre.info())
# ----> 2 display(tabela['Tipo', 'Despesas'].value_counts())
#
# File c:\Users\romel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\romel\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ('Tipo', 'Despesas')
